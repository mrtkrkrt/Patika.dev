# %% [markdown]
# ### Binary Search Tree

# %%
class Node:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key

# %% [markdown]
# ![image.png](attachment:image.png)
